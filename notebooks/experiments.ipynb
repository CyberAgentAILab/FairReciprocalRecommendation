# %%
import sys
sys.path.append("../src")

from experiments import experiment1, experiment2, experiment3

# %%
# Synthetic Data Experiment I: Section 5.1 of Tomita and Yokoyama (2024), and 8.2 of Tomita and Yokoyama (2025)
experiment1(result_dir=".", num_left=20, num_right=20, v_type='log', lambda_value=0.8, testcases=5, solver="CLARABEL")
# Out:
# ========== Seed: 0 ==========
# Naive: Match=17.60842105984251, LeftEnvy=188, RightEnvy=190, LeftGini=0.47293952926731436, RightGini=0.4725096847125408, ExecutionTime=0.0006930828094482422
# Prod: Match=18.688271746801888, LeftEnvy=183, RightEnvy=180, LeftGini=0.46673611678566407, RightGini=0.4618198136110831, ExecutionTime=0.0002830028533935547
# IterLP: Match=19.21345190266782, LeftEnvy=26, RightEnvy=14, LeftGini=0.3625866703986, RightGini=0.36194405127979873, ExecutionTime=0.14336109161376953
# TU: Match=18.878958793092856, LeftEnvy=61, RightEnvy=39, LeftGini=0.34897268446764673, RightGini=0.3265123141994975, ExecutionTime=0.0037796497344970703
# SW: Match=20.094580400637774, LeftEnvy=140, RightEnvy=143, LeftGini=0.41341907039439185, RightGini=0.4033212520092024, ExecutionTime=6.26739501953125
# NSW: Match=17.74309305217468, LeftEnvy=0, RightEnvy=0, LeftGini=0.2843025957452383, RightGini=0.27842348140134265, ExecutionTime=5.8068530559539795
#
# ========== Seed: 1 ==========
# ...

# %%
# Synthetic Data Experiment II: Section 8.3 of Tomita and Yokoyama (2025)
experiment2(result_dir=".", num_left=20, num_right=20, v_type='log', lambda_value=0.8, testcases=5, solver="CLARABEL")
# Out:
# ========== Seed: 0 ==========
# Alpha=0.0: Match=17.74309305217468, LeftEnvy=0, RightEnvy=0, LeftGini=0.2843025957452383, RightGini=0.27842348140134265, ExecutionTime=6.045501232147217
# Alpha=0.2: Match=18.591830163620465, LeftEnvy=5, RightEnvy=2, LeftGini=0.31617173204325566, RightGini=0.300632607590453, ExecutionTime=5.874505996704102
# Alpha=0.4: Match=19.353545389726342, LeftEnvy=27, RightEnvy=16, LeftGini=0.33874488679800463, RightGini=0.3229831871866808, ExecutionTime=6.005335092544556
# Alpha=0.6: Match=19.836057926378224, LeftEnvy=73, RightEnvy=48, LeftGini=0.35667205537172386, RightGini=0.3453405023024272, ExecutionTime=6.241130828857422
# Alpha=0.8: Match=20.109422473404365, LeftEnvy=115, RightEnvy=105, LeftGini=0.3841716232264143, RightGini=0.3715005272096853, ExecutionTime=6.033354043960571
# Alpha=1.0: Match=20.094580400637774, LeftEnvy=140, RightEnvy=143, LeftGini=0.41341907039439185, RightGini=0.4033212520092024, ExecutionTime=6.467501878738403
#
# ...

# %%
# Synthetic Data Experiment III: Section 8.4 of Tomita and Yokoyama (2025)
experiment3(result_dir=".", num_left=20, num_right=20, v_type='log', lambda_value=0.8, testcases=5, solver="CLARABEL", device="cpu", sinkhorn_lambda=200.0)
# Out:
# ========== Seed: 0 ==========
# Naive: Match=17.60842105984251, LeftEnvy=188, RightEnvy=190, LeftGini=0.47293952926731436, RightGini=0.4725096847125408, ExecutionTime=0.0007131099700927734
# Prod: Match=18.688271746801888, LeftEnvy=183, RightEnvy=180, LeftGini=0.46673611678566407, RightGini=0.4618198136110831, ExecutionTime=0.00011992454528808594
# IterLP: Match=19.21345190266782, LeftEnvy=26, RightEnvy=14, LeftGini=0.3625866703986, RightGini=0.36194405127979873, ExecutionTime=0.11559915542602539
# TU: Match=18.878958793092856, LeftEnvy=61, RightEnvy=39, LeftGini=0.34897268446764673, RightGini=0.3265123141994975, ExecutionTime=0.003724813461303711
# SW_LP: Match=20.094580400637774, LeftEnvy=140, RightEnvy=143, LeftGini=0.41341907039439185, RightGini=0.4033212520092024, ExecutionTime=6.5151050090789795
# NSW_LP: Match=17.74309305217468, LeftEnvy=0, RightEnvy=0, LeftGini=0.2843025957452383, RightGini=0.27842348140134265, ExecutionTime=5.95583701133728
# ...
